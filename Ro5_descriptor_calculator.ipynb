# %%
import os,re,sys,pickle,datetime,time,random,itertools
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import openpyxl
from openpyxl import load_workbook
import pandas as pd
import math
import seaborn as sns 
import umap
import umap.plot
from PIL import Image
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.multioutput import MultiOutputRegressor
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures
from sklearn.decomposition import PCA
import hdbscan
import sklearn.cluster as cluster
from sklearn.metrics import adjusted_rand_score, adjusted_mutual_info_score
randomstate = 42
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem, MolFromSmiles, PandasTools, Descriptors, Draw, PropertyMol, rdmolfiles, rdFMCS
from rdkit import RDConfig
from rdkit.ML.Descriptors import MoleculeDescriptors
from rdkit.Chem.Draw import MolsToGridImage, IPythonConsole, rdMolDraw2D
from rdkit.Chem.Draw.MolDrawing import MolDrawing,DrawingOptions, Font
DrawingOptions.bondLineWidth=1.8
DrawingOptions.includeAtomNumbers=False
size = (150, 150)
import plotly.express as px
import molplotly # requires dash version 2.0 (latest = 2.1); use pip list and pip install dash==2.0
import mols2grid
from tdc.single_pred import ADME
import useful_rdkit_utils as uru
from tqdm import tqdm
reos = uru.REOS()
ro5_calc = uru.Ro5Calculator()

# %% [markdown]
# **Calculate "rule of 5" descriptors**
#
# Lipinski's rule of five is used to evaluate "druglikeness" i.e. whether a chemical compound has the properties to be an orally active drug in humans. It is important to maintain drug-like physicochemical properties as a pharmacologically active lead structure is optimized to increase activity and selectivity. The rule describes molecular properties important for a drug's pharmacokinetics in the human body (absorption, distribution, metabolism, and excretion). Candidate drugs that conform to the RO5 tend to have lower attrition rates during clinical trials however, there are many exceptions; only about 50 % of orally administered new chemical entities actually obey the rules.
#
# Code from: https://github.com/PatWalters/useful_rdkit_utils/blob/master/notebooks/demo_REOS.ipynb

# %% [markdown]
# ## Descriptor calculation
#
# Read in data

# %%
df = pd.read_csv("drugbank_data_v1.csv")     
df = df.drop(columns=['Unnamed: 0','dimension 1','dimension 2'])      # drop some unnecessary columns
df.index = df.index.astype(int)
df
# Out:
#            CID                                              names  \
# 0       445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1       448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2       444719                     METHIONINE PHOSPHONATE|DB02151
# 3         4064                meprobamate|Meprobamic acid|DB00371
# 4         2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# ...        ...                                                ...
# 10616    60852                Ibandronic Acid|Ibandronate|DB00710
# 10617    92196                           4-Methylaminorex|DB01447
# 10618     3776   isopropanol|Isopropyl alcohol|2-Propanol|DB02325
# 10619     6834  BROMPHENIRAMINE|1-(p-Bromophenyl)-1-(2-pyridyl...
# 10620  5326813                                     DAS869|DB02850
#
#                                                   smiles  \
# 0      COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1                C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                                  CSCC[C@H](N)P(=O)(O)O
# 3                              CCCC(C)(COC(=O)N)COC(=O)N
# 4      CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# ...                                                  ...
# 10616                CCCCCN(C)CCC(O)(P(=O)(O)O)P(=O)(O)O
# 10617                          CC1C(OC(=N1)N)C2=CC=CC=C2
# 10618                                             CC(C)O
# 10619               CN(C)CCC(C1=CC=C(C=C1)Br)C2=CC=CC=N2
# 10620  CC1=C(C=CC(=C1C2=CC=C(C=C2)OC)S(=O)(=O)C)C(=O)...
#
#                                          rdmol_optimized
# 0      <img data-content="rdkit/molecule" src="data:i...
# 1      <img data-content="rdkit/molecule" src="data:i...
# 2      <img data-content="rdkit/molecule" src="data:i...
# 3      <img data-content="rdkit/molecule" src="data:i...
# 4      <img data-content="rdkit/molecule" src="data:i...
# ...                                                  ...
# 10616  <img data-content="rdkit/molecule" src="data:i...
# 10617  <img data-content="rdkit/molecule" src="data:i...
# 10618  <img data-content="rdkit/molecule" src="data:i...
# 10619  <img data-content="rdkit/molecule" src="data:i...
# 10620  <img data-content="rdkit/molecule" src="data:i...
#
# [10621 rows x 4 columns]

# %%
#df2 = df.copy()
df2 = df.head(20)
df2
# Out:
#           CID                                              names  \
# 0      445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1      448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2      444719                     METHIONINE PHOSPHONATE|DB02151
# 3        4064                meprobamate|Meprobamic acid|DB00371
# 4        2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# 5   135398619                   guanosine-5'-diphosphate|DB04315
# 6    54688261  DB02507|4-HYDROXY-3-[(1S)-3-OXO-1-PHENYLBUTYL]...
# 7      145729                DEOXYURIDINE-5'-DIPHOSPHATE|DB03413
# 8        2471  bumetanide|3-(Aminosulfonyl)-5-(butylamino)-4-...
# 9      444425                                   tl-3-093|DB01891
# 10     101544  2'-Cytidylic acid|Cytidine 2'-phosphate|2'-cmp...
# 11      65981                                Repaglinide|DB00912
# 12     445989  DB03888|N-Allyl-6-{[3-(4-bromophenyl)-1-methyl...
# 13    5289143                   LYSOPHOSPHATIDYLGLYCEROL|DB03438
# 14     447236            8-BROMOADENOSINE-5'-DIPHOSPHATE|DB04554
# 15     233240        1H-BENOXIMIDAZOLE-2-CARBOXYLIC ACID|DB03028
# 16     449088  N-(5-CYCLOPROPYL-1H-PYRAZOL-3-YL)BENZAMIDE|DB0...
# 17      16231  AMILORIDE|Amipramidin|Amyloride|AMIPRAMIDINE|3...
# 18    3260017                           Oxaloacetate Ion|DB02637
# 19       2520                     VERAPAMIL|Iproveratril|DB00661
#
#                                                smiles  \
# 0   COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1             C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                               CSCC[C@H](N)P(=O)(O)O
# 3                           CCCC(C)(COC(=O)N)COC(=O)N
# 4   CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# 5   C1=NC2=C(N1[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O...
# 6   CC(=O)C[C@@H](C1=CC=CC=C1)C2=C(C3=CC=CC=C3OC2=O)O
# 7   C1[C@@H]([C@H](O[C@H]1N2C=CC(=O)NC2=O)COP(=O)(...
# 8   CCCCNC1=C(C(=CC(=C1)C(=O)O)S(=O)(=O)N)OC2=CC=C...
# 9   C[C@@H](C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CC...
# 10  C1=CN(C(=O)N=C1N)[C@H]2[C@@H]([C@@H]([C@H](O2)...
# 11  CCOC1=C(C=CC(=C1)CC(=O)N[C@@H](CC(C)C)C2=CC=CC...
# 12  CN1C2=C(C=CC(=C2)OCCCCCCN(C)CC=C)C(=N1)C3=CC=C...
# 13  CCCCCCCCCCCCCCCC(=O)OC[C@@H](COP(=O)([O-])OC[C...
# 14  C1=NC(=C2C(=N1)N(C(=N2)Br)[C@H]3[C@@H]([C@@H](...
# 15                        C1=CC=C2C(=C1)NC(=N2)C(=O)O
# 16                  C1CC1C2=CC(=NN2)NC(=O)C3=CC=CC=C3
# 17                C1(=C(N=C(C(=N1)Cl)N)N)C(=O)N=C(N)N
# 18                            C(C(=O)C(=O)O)C(=O)[O-]
# 19  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...
#
#                                       rdmol_optimized
# 0   <img data-content="rdkit/molecule" src="data:i...
# 1   <img data-content="rdkit/molecule" src="data:i...
# 2   <img data-content="rdkit/molecule" src="data:i...
# 3   <img data-content="rdkit/molecule" src="data:i...
# 4   <img data-content="rdkit/molecule" src="data:i...
# 5   <img data-content="rdkit/molecule" src="data:i...
# 6   <img data-content="rdkit/molecule" src="data:i...
# 7   <img data-content="rdkit/molecule" src="data:i...
# 8   <img data-content="rdkit/molecule" src="data:i...
# 9   <img data-content="rdkit/molecule" src="data:i...
# 10  <img data-content="rdkit/molecule" src="data:i...
# 11  <img data-content="rdkit/molecule" src="data:i...
# 12  <img data-content="rdkit/molecule" src="data:i...
# 13  <img data-content="rdkit/molecule" src="data:i...
# 14  <img data-content="rdkit/molecule" src="data:i...
# 15  <img data-content="rdkit/molecule" src="data:i...
# 16  <img data-content="rdkit/molecule" src="data:i...
# 17  <img data-content="rdkit/molecule" src="data:i...
# 18  <img data-content="rdkit/molecule" src="data:i...
# 19  <img data-content="rdkit/molecule" src="data:i...

# %% [markdown]
# Calculate descriptors (10621 DrugBank molecules took 5 seconds)

# %%
df2['MolWt'], df2['LogP'], df2['HBD'], df2['HBA'], df2['TPSA'] = "","","","",""
df2[ro5_calc.names] = df2.smiles.apply(ro5_calc.calc_smiles).to_list()
df2
# Out:
#           CID                                              names  \
# 0      445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1      448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2      444719                     METHIONINE PHOSPHONATE|DB02151
# 3        4064                meprobamate|Meprobamic acid|DB00371
# 4        2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# 5   135398619                   guanosine-5'-diphosphate|DB04315
# 6    54688261  DB02507|4-HYDROXY-3-[(1S)-3-OXO-1-PHENYLBUTYL]...
# 7      145729                DEOXYURIDINE-5'-DIPHOSPHATE|DB03413
# 8        2471  bumetanide|3-(Aminosulfonyl)-5-(butylamino)-4-...
# 9      444425                                   tl-3-093|DB01891
# 10     101544  2'-Cytidylic acid|Cytidine 2'-phosphate|2'-cmp...
# 11      65981                                Repaglinide|DB00912
# 12     445989  DB03888|N-Allyl-6-{[3-(4-bromophenyl)-1-methyl...
# 13    5289143                   LYSOPHOSPHATIDYLGLYCEROL|DB03438
# 14     447236            8-BROMOADENOSINE-5'-DIPHOSPHATE|DB04554
# 15     233240        1H-BENOXIMIDAZOLE-2-CARBOXYLIC ACID|DB03028
# 16     449088  N-(5-CYCLOPROPYL-1H-PYRAZOL-3-YL)BENZAMIDE|DB0...
# 17      16231  AMILORIDE|Amipramidin|Amyloride|AMIPRAMIDINE|3...
# 18    3260017                           Oxaloacetate Ion|DB02637
# 19       2520                     VERAPAMIL|Iproveratril|DB00661
#
#                                                smiles  \
# 0   COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1             C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                               CSCC[C@H](N)P(=O)(O)O
# 3                           CCCC(C)(COC(=O)N)COC(=O)N
# 4   CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# 5   C1=NC2=C(N1[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O...
# 6   CC(=O)C[C@@H](C1=CC=CC=C1)C2=C(C3=CC=CC=C3OC2=O)O
# 7   C1[C@@H]([C@H](O[C@H]1N2C=CC(=O)NC2=O)COP(=O)(...
# 8   CCCCNC1=C(C(=CC(=C1)C(=O)O)S(=O)(=O)N)OC2=CC=C...
# 9   C[C@@H](C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CC...
# 10  C1=CN(C(=O)N=C1N)[C@H]2[C@@H]([C@@H]([C@H](O2)...
# 11  CCOC1=C(C=CC(=C1)CC(=O)N[C@@H](CC(C)C)C2=CC=CC...
# 12  CN1C2=C(C=CC(=C2)OCCCCCCN(C)CC=C)C(=N1)C3=CC=C...
# 13  CCCCCCCCCCCCCCCC(=O)OC[C@@H](COP(=O)([O-])OC[C...
# 14  C1=NC(=C2C(=N1)N(C(=N2)Br)[C@H]3[C@@H]([C@@H](...
# 15                        C1=CC=C2C(=C1)NC(=N2)C(=O)O
# 16                  C1CC1C2=CC(=NN2)NC(=O)C3=CC=CC=C3
# 17                C1(=C(N=C(C(=N1)Cl)N)N)C(=O)N=C(N)N
# 18                            C(C(=O)C(=O)O)C(=O)[O-]
# 19  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...
#
#                                       rdmol_optimized    MolWt     LogP  HBD  \
# 0   <img data-content="rdkit/molecule" src="data:i...  237.208 -2.85770  5.0
# 1   <img data-content="rdkit/molecule" src="data:i...  226.275  3.54170  1.0
# 2   <img data-content="rdkit/molecule" src="data:i...  185.185  0.20200  3.0
# 3   <img data-content="rdkit/molecule" src="data:i...  218.253  0.98340  2.0
# 4   <img data-content="rdkit/molecule" src="data:i...  537.576  4.63920  2.0
# 5   <img data-content="rdkit/molecule" src="data:i...  443.202 -2.45270  7.0
# 6   <img data-content="rdkit/molecule" src="data:i...  308.333  3.60960  1.0
# 7   <img data-content="rdkit/molecule" src="data:i...  388.162 -1.58870  5.0
# 8   <img data-content="rdkit/molecule" src="data:i...  364.423  3.03650  3.0
# 9   <img data-content="rdkit/molecule" src="data:i...  455.555  2.16190  4.0
# 10  <img data-content="rdkit/molecule" src="data:i...  323.198 -2.44600  5.0
# 11  <img data-content="rdkit/molecule" src="data:i...  452.595  5.21990  2.0
# 12  <img data-content="rdkit/molecule" src="data:i...  456.428  6.05980  0.0
# 13  <img data-content="rdkit/molecule" src="data:i...  483.559  3.22660  3.0
# 14  <img data-content="rdkit/molecule" src="data:i...  506.099 -0.98350  6.0
# 15  <img data-content="rdkit/molecule" src="data:i...  162.148  1.26110  2.0
# 16  <img data-content="rdkit/molecule" src="data:i...  227.267  2.53940  2.0
# 17  <img data-content="rdkit/molecule" src="data:i...  229.631 -1.29200  4.0
# 18  <img data-content="rdkit/molecule" src="data:i...  131.063 -2.21990  1.0
# 19  <img data-content="rdkit/molecule" src="data:i...  454.611  5.09308  0.0
#
#      HBA    TPSA
# 0    7.0  128.48
# 1    1.0   37.30
# 2    3.0   83.55
# 3    4.0  104.64
# 4    2.0   58.20
# 5   12.0  252.57
# 6    4.0   67.51
# 7    9.0  197.61
# 8    5.0  118.72
# 9    5.0  116.76
# 10   9.0  177.36
# 11   4.0   78.87
# 12   4.0   30.29
# 13   9.0  145.58
# 14  12.0  232.60
# 15   2.0   65.98
# 16   2.0   57.78
# 17   5.0  159.29
# 18   4.0   94.50
# 19   6.0   63.95

# %% [markdown]
# ## Search for "drug-like" compounds
#
# Add in True/False for passing Lipinski's rule of five

# %%
df2["Pass Ro5"] = (df2["MolWt"] <= 500) & (df2["LogP"] <= 5) & (df2["HBD"] <= 5) & (df2["HBA"] <= 10) & (df2["TPSA"] <= 140)
df2
# Out:
#           CID                                              names  \
# 0      445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1      448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2      444719                     METHIONINE PHOSPHONATE|DB02151
# 3        4064                meprobamate|Meprobamic acid|DB00371
# 4        2131       ambenonium|Ambenonum|Ambenonium Base|DB01122
# 5   135398619                   guanosine-5'-diphosphate|DB04315
# 6    54688261  DB02507|4-HYDROXY-3-[(1S)-3-OXO-1-PHENYLBUTYL]...
# 7      145729                DEOXYURIDINE-5'-DIPHOSPHATE|DB03413
# 8        2471  bumetanide|3-(Aminosulfonyl)-5-(butylamino)-4-...
# 9      444425                                   tl-3-093|DB01891
# 10     101544  2'-Cytidylic acid|Cytidine 2'-phosphate|2'-cmp...
# 11      65981                                Repaglinide|DB00912
# 12     445989  DB03888|N-Allyl-6-{[3-(4-bromophenyl)-1-methyl...
# 13    5289143                   LYSOPHOSPHATIDYLGLYCEROL|DB03438
# 14     447236            8-BROMOADENOSINE-5'-DIPHOSPHATE|DB04554
# 15     233240        1H-BENOXIMIDAZOLE-2-CARBOXYLIC ACID|DB03028
# 16     449088  N-(5-CYCLOPROPYL-1H-PYRAZOL-3-YL)BENZAMIDE|DB0...
# 17      16231  AMILORIDE|Amipramidin|Amyloride|AMIPRAMIDINE|3...
# 18    3260017                           Oxaloacetate Ion|DB02637
# 19       2520                     VERAPAMIL|Iproveratril|DB00661
#
#                                                smiles  \
# 0   COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1             C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                               CSCC[C@H](N)P(=O)(O)O
# 3                           CCCC(C)(COC(=O)N)COC(=O)N
# 4   CC[N+](CC)(CCNC(=O)C(=O)NCC[N+](CC)(CC)CC1=CC=...
# 5   C1=NC2=C(N1[C@H]3[C@@H]([C@@H]([C@H](O3)COP(=O...
# 6   CC(=O)C[C@@H](C1=CC=CC=C1)C2=C(C3=CC=CC=C3OC2=O)O
# 7   C1[C@@H]([C@H](O[C@H]1N2C=CC(=O)NC2=O)COP(=O)(...
# 8   CCCCNC1=C(C(=CC(=C1)C(=O)O)S(=O)(=O)N)OC2=CC=C...
# 9   C[C@@H](C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CC...
# 10  C1=CN(C(=O)N=C1N)[C@H]2[C@@H]([C@@H]([C@H](O2)...
# 11  CCOC1=C(C=CC(=C1)CC(=O)N[C@@H](CC(C)C)C2=CC=CC...
# 12  CN1C2=C(C=CC(=C2)OCCCCCCN(C)CC=C)C(=N1)C3=CC=C...
# 13  CCCCCCCCCCCCCCCC(=O)OC[C@@H](COP(=O)([O-])OC[C...
# 14  C1=NC(=C2C(=N1)N(C(=N2)Br)[C@H]3[C@@H]([C@@H](...
# 15                        C1=CC=C2C(=C1)NC(=N2)C(=O)O
# 16                  C1CC1C2=CC(=NN2)NC(=O)C3=CC=CC=C3
# 17                C1(=C(N=C(C(=N1)Cl)N)N)C(=O)N=C(N)N
# 18                            C(C(=O)C(=O)O)C(=O)[O-]
# 19  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...
#
#                                       rdmol_optimized    MolWt     LogP  HBD  \
# 0   <img data-content="rdkit/molecule" src="data:i...  237.208 -2.85770  5.0
# 1   <img data-content="rdkit/molecule" src="data:i...  226.275  3.54170  1.0
# 2   <img data-content="rdkit/molecule" src="data:i...  185.185  0.20200  3.0
# 3   <img data-content="rdkit/molecule" src="data:i...  218.253  0.98340  2.0
# 4   <img data-content="rdkit/molecule" src="data:i...  537.576  4.63920  2.0
# 5   <img data-content="rdkit/molecule" src="data:i...  443.202 -2.45270  7.0
# 6   <img data-content="rdkit/molecule" src="data:i...  308.333  3.60960  1.0
# 7   <img data-content="rdkit/molecule" src="data:i...  388.162 -1.58870  5.0
# 8   <img data-content="rdkit/molecule" src="data:i...  364.423  3.03650  3.0
# 9   <img data-content="rdkit/molecule" src="data:i...  455.555  2.16190  4.0
# 10  <img data-content="rdkit/molecule" src="data:i...  323.198 -2.44600  5.0
# 11  <img data-content="rdkit/molecule" src="data:i...  452.595  5.21990  2.0
# 12  <img data-content="rdkit/molecule" src="data:i...  456.428  6.05980  0.0
# 13  <img data-content="rdkit/molecule" src="data:i...  483.559  3.22660  3.0
# 14  <img data-content="rdkit/molecule" src="data:i...  506.099 -0.98350  6.0
# 15  <img data-content="rdkit/molecule" src="data:i...  162.148  1.26110  2.0
# 16  <img data-content="rdkit/molecule" src="data:i...  227.267  2.53940  2.0
# 17  <img data-content="rdkit/molecule" src="data:i...  229.631 -1.29200  4.0
# 18  <img data-content="rdkit/molecule" src="data:i...  131.063 -2.21990  1.0
# 19  <img data-content="rdkit/molecule" src="data:i...  454.611  5.09308  0.0
#
#      HBA    TPSA  Pass Ro5
# 0    7.0  128.48      True
# 1    1.0   37.30      True
# 2    3.0   83.55      True
# 3    4.0  104.64      True
# 4    2.0   58.20     False
# 5   12.0  252.57     False
# 6    4.0   67.51      True
# 7    9.0  197.61     False
# 8    5.0  118.72      True
# 9    5.0  116.76      True
# 10   9.0  177.36     False
# 11   4.0   78.87     False
# 12   4.0   30.29     False
# 13   9.0  145.58     False
# 14  12.0  232.60     False
# 15   2.0   65.98      True
# 16   2.0   57.78      True
# 17   5.0  159.29     False
# 18   4.0   94.50      True
# 19   6.0   63.95     False

# %%
df_ro5_pass = df2.loc[df2['Pass Ro5']==True]
df_ro5_pass
# Out:
#          CID                                              names  \
# 0     445722  DB03657|N-(methoxycarbonyl)-beta-D-glucopyrano...
# 1     448006  (+)-2-(4-biphenyl)propionic acid|2-(1,1'-BIPHE...
# 2     444719                     METHIONINE PHOSPHONATE|DB02151
# 3       4064                meprobamate|Meprobamic acid|DB00371
# 6   54688261  DB02507|4-HYDROXY-3-[(1S)-3-OXO-1-PHENYLBUTYL]...
# 8       2471  bumetanide|3-(Aminosulfonyl)-5-(butylamino)-4-...
# 9     444425                                   tl-3-093|DB01891
# 15    233240        1H-BENOXIMIDAZOLE-2-CARBOXYLIC ACID|DB03028
# 16    449088  N-(5-CYCLOPROPYL-1H-PYRAZOL-3-YL)BENZAMIDE|DB0...
# 18   3260017                           Oxaloacetate Ion|DB02637
#
#                                                smiles  \
# 0   COC(=O)N[C@H]1[C@@H]([C@H]([C@@H]([C@H](O1)CO)...
# 1             C[C@@H](C1=CC=C(C=C1)C2=CC=CC=C2)C(=O)O
# 2                               CSCC[C@H](N)P(=O)(O)O
# 3                           CCCC(C)(COC(=O)N)COC(=O)N
# 6   CC(=O)C[C@@H](C1=CC=CC=C1)C2=C(C3=CC=CC=C3OC2=O)O
# 8   CCCCNC1=C(C(=CC(=C1)C(=O)O)S(=O)(=O)N)OC2=CC=C...
# 9   C[C@@H](C(=O)N[C@@H](C(C)C)C(=O)N[C@@H](CC1=CC...
# 15                        C1=CC=C2C(=C1)NC(=N2)C(=O)O
# 16                  C1CC1C2=CC(=NN2)NC(=O)C3=CC=CC=C3
# 18                            C(C(=O)C(=O)O)C(=O)[O-]
#
#                                       rdmol_optimized    MolWt    LogP  HBD  \
# 0   <img data-content="rdkit/molecule" src="data:i...  237.208 -2.8577  5.0
# 1   <img data-content="rdkit/molecule" src="data:i...  226.275  3.5417  1.0
# 2   <img data-content="rdkit/molecule" src="data:i...  185.185  0.2020  3.0
# 3   <img data-content="rdkit/molecule" src="data:i...  218.253  0.9834  2.0
# 6   <img data-content="rdkit/molecule" src="data:i...  308.333  3.6096  1.0
# 8   <img data-content="rdkit/molecule" src="data:i...  364.423  3.0365  3.0
# 9   <img data-content="rdkit/molecule" src="data:i...  455.555  2.1619  4.0
# 15  <img data-content="rdkit/molecule" src="data:i...  162.148  1.2611  2.0
# 16  <img data-content="rdkit/molecule" src="data:i...  227.267  2.5394  2.0
# 18  <img data-content="rdkit/molecule" src="data:i...  131.063 -2.2199  1.0
#
#     HBA    TPSA  Pass Ro5
# 0   7.0  128.48      True
# 1   1.0   37.30      True
# 2   3.0   83.55      True
# 3   4.0  104.64      True
# 6   4.0   67.51      True
# 8   5.0  118.72      True
# 9   5.0  116.76      True
# 15  2.0   65.98      True
# 16  2.0   57.78      True
# 18  4.0   94.50      True

# %%
df_ro5_pass.to_csv('Ro5_passes.csv', index = True)

# %% [markdown]
# ## Add the descriptors to an existing data set

# %%
df = pd.read_csv("drugbank_data_1.csv")     
df = df.drop(columns=['Unnamed: 0'])
df.index = df.index.astype(int)
df2 = df.copy()
df2

# %%
df2['MolWt'], df2['LogP'], df2['HBD'], df2['HBA'], df2['TPSA'] = "","","","",""
df2[ro5_calc.names] = df2.smiles.apply(ro5_calc.calc_smiles).to_list()
df2["Pass Ro5"] = (df2["MolWt"] <= 500) & (df2["LogP"] <= 5) & (df2["HBD"] <= 5) & (df2["HBA"] <= 10) & (df2["TPSA"] <= 140)
df2

# %%
df2.to_csv('drugbank_data_v2_Ro5.csv', index = True)
